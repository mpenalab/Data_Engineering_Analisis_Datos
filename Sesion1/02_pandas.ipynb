# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached numpy-2.3.5-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# Using cached numpy-2.3.5-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]━━━━ 3/4 [pandas]
# ...

# %%
import pandas as pd

# %%
# Crear dataframe a partir de una lista de listas

data = [['Juan', 25], ['Pedro', 34], ['Luis', 45, 10]]

df = pd.DataFrame(data, columns=['Nombre', 'Edad', 'Peso'])
df
# Out:
#   Nombre  Edad  Peso
# 0   Juan    25   NaN
# 1  Pedro    34   NaN
# 2   Luis    45  10.0

# %%
# Crear dataframe a partir de un diccionario

data = {
    'Nombre': ['Juan', 'Pedro', 'Luis'],
    'Edad': [25, 26, 34]
}

df = pd.DataFrame(data)
df
# Out:
#   Nombre  Edad
# 0   Juan    25
# 1  Pedro    26
# 2   Luis    34

# %%
df = pd.read_csv('data/data1.csv')

df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_csv('data/data2', sep='|')

df
# Out:
#   nombre  edad     ciudad
# 0   Juan   NaN     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df = pd.read_csv('data/data_without_header', sep=',', header=None, names=['Nombre', 'Edad', 'Ciudad'])
df
# Out:
#   Nombre  Edad     Ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_json('data/data.json')
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
## Metodos de pandas

df.head()
df.tail()
df.info()
df.describe()

# %%
df.head(1)
# Out:
#   nombre  edad  ciudad
# 0   Juan    25  Madrid

# %%
df.tail(1)
# Out:
#   nombre  edad   ciudad
# 2  Pedro    35  Sevilla

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nombre  3 non-null      object
#  1   edad    3 non-null      int64
#  2   ciudad  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#        edad
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df.count()
# Out:
# nombre    3
# edad      3
# ciudad    3
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
type(df[['nombre']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['nombre', 'edad']]
# Out:
#   nombre  edad
# 0   Juan    25
# 1  María    30
# 2  Pedro    35

# %%
df
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df.loc[[0,2]]
# Out:
#   nombre  edad   ciudad
# 0   Juan    25   Madrid
# 2  Pedro    35  Sevilla

# %%
df[df['edad'] > 30]
# Out:
#   nombre  edad   ciudad
# 2  Pedro    35  Sevilla

# %%
data = {
    'Grupo': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Valor': [10, 20, 15, 25, 12, 18]
}

df = pd.DataFrame(data)

# %%
df.groupby('Grupo').sum()
# Out:
#        Valor
# Grupo
# A         37
# B         63

# %%
df.groupby('Grupo').mean()
# Out:
#            Valor
# Grupo
# A      12.333333
# B      21.000000

# %%
df = pd.read_csv('data/data2', sep='|')
df
# Out:
#   nombre  edad     ciudad
# 0   Juan   NaN     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df.dropna()
# Out:
#   nombre  edad     ciudad
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df
# Out:
#   nombre  edad     ciudad
# 0   Juan   NaN     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df.dropna(subset=['edad'])
# Out:
#   nombre  edad     ciudad
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df
# Out:
#   nombre  edad     ciudad
# 0   Juan   NaN     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df.fillna(df['edad'].mean(), inplace=True)
df
# Out:
#   nombre  edad     ciudad
# 0   Juan  32.5     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
df
# Out:
#   nombre  edad     ciudad
# 0   Juan  32.5     Madrid
# 1  María  30.0  Barcelona
# 2  Pedro  35.0    Sevilla

# %%
data = {
    'A': [1, 2, 3, 4],
    'B': [6, 7, 8, 9]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    A  B
# 0  1  6
# 1  2  7
# 2  3  8
# 3  4  9

# %%
df['A_nuevo'] = df['A'].apply(lambda x: x**2)

# %%
df
# Out:
#    A  B  A_nuevo
# 0  1  6        1
# 1  2  7        4
# 2  3  8        9
# 3  4  9       16
